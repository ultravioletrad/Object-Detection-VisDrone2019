# %%
import os
import io
import sys
import scipy.io
import scipy.misc
import itertools

#from glob2 import glob
from six import BytesIO
import pandas as pd
import tensorflow as tf
from sklearn import preprocessing
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Conv2DTranspose
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Reshape
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K



import csv


import matplotlib 
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as patches


import pathlib

import PIL
from PIL import Image
from PIL import ImageColor
from PIL import ImageDraw
from PIL import ImageFont
from PIL import ImageOps


import traceback
import numpy.random as npr
from tensorflow.keras.layers import *


#from keras import backend as K

# %%
tf.compat.v1.keras.layers.enable_v2_dtype_behavior()

#from tensorflow.python.framework.ops import disable_eager_execution
#disable_eager_execution()

from tensorflow.python.compiler.mlcompute import mlcompute
mlcompute.set_mlc_device(device_name='any')


#from tensorflow.python.compiler.mlcompute import mlcompute
#mlcompute.set_mlc_device(device_name='any')
#tf.compat.v1.disable_eager_execution()
print("Num GPUs Available: ", len(tf.config.list_physical_devices('cpu')))
print(" Physical devices:" , tf.config.list_physical_devices('cpu'))
print("is_apple_mlc_enabled %s" % mlcompute.is_apple_mlc_enabled())
print("is_tf_compiled_with_apple_mlc %s" % mlcompute.is_tf_compiled_with_apple_mlc())
print(f"eagerly? {tf.executing_eagerly()}")

print(tf.config.list_logical_devices())
# Out:
# WARNING:tensorflow:From /var/folders/y5/383sdlcn58g_zqg_48133p0c0000gn/T/ipykernel_1061/2025963283.py:1: The name tf.keras.layers.enable_v2_dtype_behavior is deprecated. Please use tf.compat.v1.keras.layers.enable_v2_dtype_behavior instead.
#
# Num GPUs Available:  0
#  Physical devices: []
# is_apple_mlc_enabled True
# is_tf_compiled_with_apple_mlc True
# eagerly? True
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')]

# %%
#from keras.models import Input, Model
from tensorflow.keras.layers.experimental import preprocessing 
from tensorflow.keras.optimizers import Adam
from IPython.display import clear_output
from IPython.display import Image, display




print("\u2022 Using TensorFlow Version:", tf.__version__)
# Out:
# • Using TensorFlow Version: 2.4.0-rc0

# %%
# Check available GPU devices.
print("The following GPU devices are available: %s" % tf.test.gpu_device_name())
# Out:
# The following GPU devices are available:

# %%
"""
Problem: Detecting objects in aerial images
"""
# Out:
# '\nProblem: Detecting objects in aerial images\n'

# %%
"""
https://github.com/VisDrone/VisDrone-Dataset
Citation:
@ARTICLE{9573394,
  author={Zhu, Pengfei and Wen, Longyin and Du, Dawei and Bian, Xiao and Fan, Heng and Hu, Qinghua and Ling, Haibin},
  journal={IEEE Transactions on Pattern Analysis and Machine Intelligence}, 
  title={Detection and Tracking Meet Drones Challenge}, 
  year={2021},
  volume={},
  number={},
  pages={1-1},
  doi={10.1109/TPAMI.2021.3119563}}
"""
"""
VisDromes2019 is a large-scale benchmark dataset with carefully annotated ground-truth for various important 
computer vision tasks, named VisDrone, to make vision meet drones. The VisDrone2019 dataset is collected by 
the AISKYEYE team at Lab of Machine Learning and Data Mining , Tianjin University, China. 
The benchmark dataset consists of 288 video clips formed by 261,908 frames and 10,209 static images,
captured by various drone-mounted cameras, covering a wide range of aspects including location(taken from 14 different cities separated by thousands of kilometers in China), 
environment (urban and country), 
objects (pedestrian, vehicles, bicycles, etc.), and 
density (sparse and crowded scenes).
Note that, the dataset was collected using various drone platforms (i.e., drones with different models),
in different scenarios, and under various weather and lighting conditions. 
These frames are manually annotated with more than 2.6 million bounding boxes of targets of frequent interests,
such as pedestrians, cars, bicycles, and tricycles. Some important attributes including scene visibility,
object class and occlusion, are also provided for better data utilization.
"""
#https://github.com/VisDrone/VisDrone2018-DET-toolkit
#Annotation file format
 #<bbox_left>,<bbox_top>,<bbox_width>,<bbox_height>,<score>,<object_category>,<truncation>,<occlusion>


   # Name                                                  Description
#-------------------------------------------------------------------------------------------------------------------------------     
 #<bbox_left>	     The x coordinate of the top-left corner of the predicted bounding box

 #<bbox_top>	     The y coordinate of the top-left corner of the predicted object bounding box

 #<bbox_width>	     The width in pixels of the predicted object bounding box

#<bbox_height>	     The height in pixels of the predicted object bounding box

#   <score>	     The score in the DETECTION file indicates the confidence of the predicted bounding box enclosing 
                    # an object instance.
                    # The score in GROUNDTRUTH file is set to 1 or 0. 1 indicates the bounding box is considered in evaluation, 
                    # while 0 indicates the bounding box will be ignored.
                      
#<object_category>    The object category indicates the type of annotated object, (i.e., ignored regions(0), pedestrian(1), 
                     #people(2), bicycle(3), car(4), van(5), truck(6), tricycle(7), awning-tricycle(8), bus(9), motor(10), 
                     #others(11))
                      
#<truncation>	     The score in the DETECTION result file should be set to the constant -1.
                    # The score in the GROUNDTRUTH file indicates the degree of object parts appears outside a frame 
                     #(i.e., no truncation = 0 (truncation ratio 0%), and partial truncation = 1 (truncation ratio 1% ~ 50%)).
                      
#<occlusion>	     The score in the DETECTION file should be set to the constant -1.
                    # The score in the GROUNDTRUTH file indicates the fraction of objects being occluded (i.e., no occlusion = 0 
                     #(occlusion ratio 0%), partial occlusion = 1 (occlusion ratio 1% ~ 50%), and heavy occlusion = 2 
                     #(occlusion ratio 50% ~ 100%)).
# Out:
# '\nVisDromes2019 is a large-scale benchmark dataset with carefully annotated ground-truth for various important \ncomputer vision tasks, named VisDrone, to make vision meet drones. The VisDrone2019 dataset is collected by \nthe AISKYEYE team at Lab of Machine Learning and Data Mining , Tianjin University, China. \nThe benchmark dataset consists of 288 video clips formed by 261,908 frames and 10,209 static images,\ncaptured by various drone-mounted cameras, covering a wide range of aspects including location(taken from 14 different cities separated by thousands of kilometers in China), \nenvironment (urban and country), \nobjects (pedestrian, vehicles, bicycles, etc.), and \ndensity (sparse and crowded scenes).\nNote that, the dataset was collected using various drone platforms (i.e., drones with different models),\nin different scenarios, and under various weather and lighting conditions. \nThese frames are manually annotated with more than 2.6 million bounding boxes of targets of frequent interests,\nsuch as pedestrians, cars, bicycles, and tricycles. Some important attributes including scene visibility,\nobject class and occlusion, are also provided for better data utilization.\n'

# %%
#Explore an image from the dataset
# summarize some details about the image

path_image='Downloads/VisDrone2019-DET-train/images/0000002_00005_d_0000014.jpg'
# load the image and convert into
# numpy array
img = PIL.Image.open(path_image)
  
# asarray() class is used to convert
# PIL images into NumPy arrays
np_imagetest = np.array(img)
  
# <class 'numpy.ndarray'>
print(type(np_imagetest))
W,H,D= (np_imagetest).shape 
#  shape
print((np_imagetest).shape)
# Out:
# <class 'numpy.ndarray'>
# (540, 960, 3)

# %%
# extract image id
path_img=path_image
image_id = path_img.split('/')[-4:]
path_mask= image_id[0]+'/'+image_id[1]+'/masks/'+image_id[3]
print(path_mask)
print(image_id[0])
# Out:
# Downloads/VisDrone2019-DET-train/masks/0000002_00005_d_0000014.jpg
# Downloads

# %%
#Visualizing the images
# Create figure and axes
fig = plt.figure(frameon=False)
  
ax = plt.Axes(fig, [0., 0., 1., 1.])
ax.set_axis_off()
fig.add_axes(ax)

# Display the image
ax.imshow(np_imagetest)

# %%
def process_img(file_path):
    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.uint8)
    #img = tf.image.resize(img, size= (height ,width))
    return img

# %%
#Define function to create masks for images from corresponding annotation files in VisDrone2019 dataset

def create_mask(image_filepath,anno_filepath): 
    
    path_b=anno_filepath
    path_img=image_filepath

     # extract image id
    image_id = path_img.split('/')[-4:]
    path_mask=image_id[0]+'/'+image_id[1]+'/masks/'+image_id[3]
    data_df = pd.read_csv(path_b, delimiter = ',',header=None)
    
    #<bbox_left>,<bbox_top>,<bbox_width>,<bbox_height>,<score>,<object_category>,<truncation>,<occlusion>
    #(x1,y1,w1,h1,sc,cat,tr,oc)= line
     
    data_df.columns=['x1','y1','w1','h1','sc','cat','tr','oc']    
    #print(data_df.info())
    listdf=data_df[['x1','y1','w1','h1']].values.tolist()
    #image_id = path_img.split('/')[-1]
    
    img = PIL.Image.open(path_img)
  
    # asarray() class is used to convert
    # PIL images into NumPy arrays
    np_image = np.array(img)

    # <class 'numpy.ndarray'>
    
    W,H,D= (np_image).shape 
    x = np.zeros(np_image.shape[:-1])+3
    fig, ax = plt.subplots(1)
    for i in range(len(listdf)): 
        [x1,y1,w1,h1]=listdf[i]
        bbox_list=[x1,y1,w1,h1]
    
        bbox=bbox_list
        #print(bbox)
        rect = patches.Rectangle((bbox[0], bbox[1]), bbox[2], bbox[3], linewidth=1,
                         edgecolor='r', facecolor="g")
 
        ax.add_patch(rect)
        plt.axis('off')
    
        ax.imshow(x)
    # Create figure and axes
    
    buff=io.BytesIO()
    fig.savefig(buff, format='jpg', dpi='figure')
    buff.seek(0)
    #print(buff)
    img_mask = np.frombuffer(buff.getvalue(), dtype= 'uint8',count= -1, offset=0)
    #img1=Image.fromarray(img_arr)
    #print(img1)
    
    fig.savefig(path_mask, bbox_inches='tight', pad_inches=0)   
    buff.close()
    plt.close(fig) 
    
    mask_arr = PIL.Image.open(path_mask)
    arr = np.array(mask_arr)
    #print(mask_arr.shape)
    #mask_arr.reshape(W,H,D)
    #print(mask_arr.shape)
    mask_bool=np.where(arr>0,1,0)
    mask=np.ma.MaskedArray(arr,mask_bool)
    im = PIL.Image.fromarray(mask)
    im.save(path_mask)
    mask_arr.close()
    im.close()
    #mask.reshape(W,H,D)
    #img_mask = PIL.Image.fromarray(np.uint8(img_mask))
    #img_mask.save(path_mask)
    #return im

# %%
 
train_dataset_dir = 'Downloads/VisDrone2019-DET-train' 
test_dataset_dir = 'Downloads/VisDrone2019-DET-test-dev'
val_dataset_dir = 'Downloads/VisDrone2019-DET-val'
# define data locations for images and annotations
train_images_dir = train_dataset_dir + '/images/'
train_annotations_dir = train_dataset_dir + '/annotations/'
train_masks_dir = train_dataset_dir + '/masks/'


test_images_dir = test_dataset_dir + '/images/'
test_annotations_dir = test_dataset_dir + '/annotations/'
test_masks_dir = test_dataset_dir + '/masks/'

val_images_dir = val_dataset_dir + '/images/'
val_annotations_dir = val_dataset_dir + '/annotations/'
val_masks_dir = val_dataset_dir + '/masks/'

# %%
#Explore data dirs
num_images=len(sorted(os.listdir(train_masks_dir)))
print(num_images)
#print(sorted(os.listdir(train_images_dir)))
print(sorted(os.listdir(train_masks_dir)))
# Out:
# 1552
# ['.DS_Store', '0000002_00005_d_0000014.jpg', '0000002_00448_d_0000015.jpg', '0000003_00231_d_0000016.jpg', '0000007_04999_d_0000036.jpg', '0000007_05499_d_0000037.jpg', '0000007_05999_d_0000038.jpg', '0000008_00889_d_0000039.jpg', '0000008_01999_d_0000040.jpg', '0000008_02499_d_0000041.jpg', '0000008_02999_d_0000042.jpg', '0000008_03499_d_0000043.jpg', '0000008_03999_d_0000044.jpg', '0000008_04499_d_0000045.jpg', '0000010_00569_d_0000056.jpg', '0000010_05149_d_0000057.jpg', '0000010_05291_d_0000058.jpg', '0000013_00465_d_0000067.jpg', '0000016_00420_d_0000068.jpg', '0000016_01352_d_0000069.jpg', '0000030_00754_d_0000036.jpg', '0000031_00000_d_0000037.jpg', '0000031_02000_d_0000041.jpg', '0000031_03527_d_0000043.jpg', '0000036_00500_d_0000046.jpg', '0000036_03591_d_0000048.jpg', '0000037_01494_d_0000052.jpg', '0000039_00000_d_0000055.jpg', '0000039_05300_d_0000061.jpg', '0000039_05625_d_0000062.jpg', '0000040_01000_d_0000066.jpg', '0000040_01500_d_0000067.jpg', '0000040_02454_d_0000068.jpg', '0000040_03288_d_0000069.jpg', '0000040_03752_d_0000070.jpg', '0000040_04284_d_0000071.jpg', '0000042_01000_d_0000074.jpg', '0000042_02231_d_0000075.jpg', '0000042_02421_d_0000076.jpg', '0000043_00500_d_0000077.jpg', '0000045_00000_d_0000083.jpg', '0000045_00500_d_0000084.jpg', '0000045_01032_d_0000085.jpg', '0000045_01500_d_0000086.jpg', '0000046_00000_d_0000087.jpg', '0000046_00720_d_0000088.jpg', '0000047_01000_d_0000090.jpg', '0000047_02500_d_0000093.jpg', '0000047_03500_d_0000095.jpg', '0000048_01989_d_0000098.jpg', '0000050_00500_d_0000104.jpg', '0000056_00727_d_0000111.jpg', '0000059_01886_d_0000114.jpg', '0000068_00001_d_0000001.jpg', '0000068_00460_d_0000002.jpg', '0000068_00571_d_0000003.jpg', '0000068_01001_d_0000004.jpg', '0000068_01500_d_0000005.jpg', '0000068_02104_d_0000006.jpg', '0000068_02648_d_0000007.jpg', '0000068_02805_d_0000008.jpg', '0000068_03174_d_0000009.jpg', '0000068_03388_d_0000010.jpg', '0000068_03581_d_0000011.jpg', '0000068_03714_d_0000012.jpg', '0000068_03918_d_0000013.jpg', '0000068_04169_d_0000014.jpg', '0000070_04722_d_0000001.jpg', '0000070_05163_d_0000002.jpg', '0000070_05312_d_0000003.jpg', '0000070_05776_d_0000004.jpg', '0000070_05880_d_0000005.jpg', '0000070_06990_d_0000007.jpg', '0000071_00007_d_0000001.jpg', '0000071_02729_d_0000002.jpg', '0000071_03136_d_0000003.jpg', '0000071_03281_d_0000004.jpg', '0000071_03470_d_0000005.jpg', '0000071_03522_d_0000006.jpg', '0000071_04085_d_0000007.jpg', '0000071_05298_d_0000008.jpg', '0000071_06447_d_0000009.jpg', '0000071_06896_d_0000010.jpg', '0000071_06967_d_0000011.jpg', '0000071_07349_d_0000012.jpg', '0000071_07913_d_0000013.jpg', '0000072_00000_d_0000001.jpg', '0000072_00137_d_0000002.jpg', '0000072_03425_d_0000004.jpg', '0000072_04493_d_0000005.jpg', '0000072_05285_d_0000006.jpg', '0000072_05564_d_0000007.jpg', '0000072_05654_d_0000008.jpg', '0000072_05827_d_0000009.jpg', '0000072_06173_d_0000010.jpg', '0000072_07242_d_0000011.jpg', '0000072_07660_d_0000012.jpg', '0000072_08702_d_0000013.jpg', '0000072_09163_d_0000014.jpg', '0000076_00004_d_0000001.jpg', '0000076_00352_d_0000002.jpg', '0000076_00616_d_0000003.jpg', '0000076_01012_d_0000004.jpg', '0000076_01444_d_0000005.jpg', '0000076_01601_d_0000006.jpg', '0000076_01792_d_0000007.jpg', '0000076_01975_d_0000008.jpg', '0000076_02667_d_0000010.jpg', '0000076_03315_d_0000011.jpg', '0000076_03689_d_0000012.jpg', '0000076_03930_d_0000013.jpg', '0000076_04200_d_0000014.jpg', '0000076_04382_d_0000015.jpg', '0000076_04674_d_0000016.jpg', '0000076_04925_d_0000017.jpg', '0000076_04999_d_0000018.jpg', '0000076_05079_d_0000019.jpg', '0000079_00507_d_0000001.jpg', '0000079_00761_d_0000002.jpg', '0000079_01062_d_0000003.jpg', '0000079_01316_d_0000004.jpg', '0000079_01515_d_0000005.jpg', '0000079_01673_d_0000006.jpg', '0000079_01783_d_0000007.jpg', '0000079_02443_d_0000008.jpg', '0000080_00002_d_0000001.jpg', '0000084_00000_d_0000001.jpg', '0000084_00281_d_0000002.jpg', '0000084_01436_d_0000004.jpg', '0000084_01781_d_0 ...

# %%
#
def process_dataset(dataset_dir):
        # define data locations for images and annotations
        images_dir = dataset_dir + '/images/'
        annotations_dir = dataset_dir + '/annotations/'
        masks_dir = dataset_dir + '/masks/'
        
        # Iterate through all files in the folder to 
        #add class, images and annotaions
        imgId =[]
        imgPath = []
        maskPath = []
        bboxPath = []
        #for i in range(num_images):
        img_fileslist=list(sorted(os.listdir(images_dir)))
        annotations_fileslist=list(sorted(os.listdir(annotations_dir)))
        for filename in img_fileslist:   
               
               # setting image file
               path_img = images_dir + filename
               path_mask = masks_dir + filename
               # adding images and annotations to dataset
               #self.add_image('dataset', image_id=image_id, path=path_img, annotation= path_bb)
               imgPath.append(path_img)
               maskPath.append(path_mask) 
        for filename in annotations_fileslist:
               # extract image id
               #image_id =  filename[-4:]
                # setting annotations file
               path_bb =  annotations_dir + filename
               bboxPath.append(path_bb)
               #imgId.append(image_id)
           
        return imgPath,bboxPath,maskPath

# %%
train_files,trainAnno_files,train_masks = process_dataset(train_dataset_dir)
test_files,testAnno_files,test_masks = process_dataset(test_dataset_dir)
val_files,valAnno_files,val_masks = process_dataset(val_dataset_dir)

# %%
print("Number of samples:", len(train_masks)) 
for input_path, target_path in zip(train_files[:10], train_masks[:10]): print(input_path, "|", target_path)
# Out:
# Number of samples: 6471
# Downloads/VisDrone2019-DET-train/images/0000002_00005_d_0000014.jpg | Downloads/VisDrone2019-DET-train/masks/0000002_00005_d_0000014.jpg
# Downloads/VisDrone2019-DET-train/images/0000002_00448_d_0000015.jpg | Downloads/VisDrone2019-DET-train/masks/0000002_00448_d_0000015.jpg
# Downloads/VisDrone2019-DET-train/images/0000003_00231_d_0000016.jpg | Downloads/VisDrone2019-DET-train/masks/0000003_00231_d_0000016.jpg
# Downloads/VisDrone2019-DET-train/images/0000007_04999_d_0000036.jpg | Downloads/VisDrone2019-DET-train/masks/0000007_04999_d_0000036.jpg
# Downloads/VisDrone2019-DET-train/images/0000007_05499_d_0000037.jpg | Downloads/VisDrone2019-DET-train/masks/0000007_05499_d_0000037.jpg
# Downloads/VisDrone2019-DET-train/images/0000007_05999_d_0000038.jpg | Downloads/VisDrone2019-DET-train/masks/0000007_05999_d_0000038.jpg
# Downloads/VisDrone2019-DET-train/images/0000008_00889_d_0000039.jpg | Downloads/VisDrone2019-DET-train/masks/0000008_00889_d_0000039.jpg
# Downloads/VisDrone2019-DET-train/images/0000008_01999_d_0000040.jpg | Downloads/VisDrone2019-DET-train/masks/0000008_01999_d_0000040.jpg
# Downloads/VisDrone2019-DET-train/images/0000008_02499_d_0000041.jpg | Downloads/VisDrone2019-DET-train/masks/0000008_02499_d_0000041.jpg
# Downloads/VisDrone2019-DET-train/images/0000008_02999_d_0000042.jpg | Downloads/VisDrone2019-DET-train/masks/0000008_02999_d_0000042.jpg

# %%
# Display input image 
display(Image(filename=train_files[77]))

# Display auto-contrast version of corresponding target (per-pixel categories)
img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.load_img(train_masks[77]))

display(img)
np.shape(img)
# Out:
# <PIL.Image.Image image mode=RGB size=334x188 at 0x14CE7B0A0>
# (188, 334, 3)

# %%
#Creating masks in the local storage 
#Do not run this cell if the required data is already present
for img_file,anno_file in list(zip(train_files[1591:1621],trainAnno_files[1591:1621])):
     create_mask(img_file,anno_file)

# %%
#Creating masks in the local storage 
#Do not run this cell if the required data is already present
for img_file,anno_file in list(zip(test_files[371:411],testAnno_files[371:411])):
    create_mask(img_file,anno_file)

# %%
#Creating masks in the local storage 
#Do not run this cell if the required data is already present
for img_file,anno_file in list(zip(val_files[551:591],valAnno_files[551:591])):
    create_mask(img_file,anno_file)

# %%
#Functions to load images & masks to model input
def loadimage(x):
    img = PIL.Image.open(x)
    input_image = img.resize((160,160),PIL.Image.ANTIALIAS)
    input_image=np.asarray(input_image)
    #input_image= np.absolute((input_image-np.mean(input_image))/np.sqrt(np.var(input_image)))
    return input_image/255
def loadmask(y):
    img = PIL.Image.open(y)
    input_mask = img.resize((160,160),PIL.Image.ANTIALIAS)
    input_mask=np.asarray(input_mask, dtype='int')
    #input_mask= np.absolute((input_mask-np.mean(input_mask))/np.sqrt(np.var(input_mask)))
    #input_mask=(np.invert(input_mask))
    #input_mask=input_mask.astype(int)
    #input_mask=np.where(input_mask!=0,1,input_mask)
    #input_mask=np.where(input_mask==255,0,input_mask)
    return input_mask/255

# %%
#Check loadimage funtion to load image to model input
sample_image=loadimage(train_files[11])
sample_image=np.resize(sample_image,(160,160,3))
print(sample_image.shape)
plt.imshow(sample_image)
# Out:
# (160, 160, 3)

# %%
#Check loadmask funtion to load masks to model input
sample_mask=loadmask(train_masks[11])
sample_mask=np.resize(sample_mask,(160,160,3))
np.shape(sample_mask)
print(sample_mask)
plt.imshow(sample_mask)
# Out:
# [[[0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   ...
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]]
#
#  [[0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   ...
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]]
#
#  [[0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   ...
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]]
#
#  ...
#
#  [[0.50588235 0.11764706 0.20392157]
#   [0.15686275 0.4627451  0.        ]
#   [0.         0.53333333 0.03137255]
#   ...
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]]
#
#  [[0.50588235 0.11764706 0.20392157]
#   [0.15686275 0.4627451  0.        ]
#   [0.         0.53333333 0.03137255]
#   ...
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]]
#
#  [[0.50588235 0.11764706 0.20392157]
#   [0.15686275 0.4627451  0.        ]
#   [0.         0.53333333 0.03137255]
#   ...
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]
#   [0.26666667 0.         0.3254902 ]]]

# %%
class DroneImages(tf.keras.utils.Sequence):
    """Helper to iterate over the data (as Numpy arrays)."""

    def __init__(self, batch_size, img_size, input_img_paths, target_img_paths):
        self.batch_size = batch_size
        self.img_size = img_size
        self.input_img_paths = input_img_paths
        self.target_img_paths = target_img_paths

    def __len__(self):
        return len(self.target_img_paths) // self.batch_size

    def __getitem__(self, idx):
        """Returns tuple (input, target) correspond to batch #idx."""
        i = idx * self.batch_size
        batch_input_img_paths = self.input_img_paths[i : i + self.batch_size]
        batch_target_img_paths = self.target_img_paths[i : i + self.batch_size]
        x = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="float32")
        for j, path_img in enumerate(batch_input_img_paths):
            img = loadimage(path_img)
            x[j] = img
        y = np.zeros((self.batch_size,) + self.img_size + (3,), dtype="uint8")
        for j, path_mask in enumerate(batch_target_img_paths):
            img = loadmask(path_mask)
            #y[j] = np.expand_dims(img, 2)
            y[j] = img
            # Ground truth labels are  0, 1:
            
        return x, y

# %%
train_dataset_images = train_files[0:1620]
train_dataset_masks = train_masks[0:1620]

# %%
test_dataset_images = test_files[0:410]
test_dataset_masks = test_masks[0:410]

# %%
val_dataset_images = val_files[0:548]
val_dataset_masks = val_masks[0:548]

# %%
train_size =len(train_dataset_images)
val_size = len(val_dataset_images)
test_size = len(test_dataset_images)


num_examples = train_size + val_size + test_size
print("num_examples:",num_examples)
train_ratio=train_size/num_examples
test_ratio=test_size/num_examples
val_ratio=val_size/num_examples
print("test-train-val-split:")
print("train_size:",train_size, "test_size:",test_size,"val_size:",val_size )
train_length=train_size
test_length=test_size
val_length=val_size
print(f"train_ratio:{train_ratio:.2f}")
print(f"test_ratio:{test_ratio:.2f}")
print(f"val_ratio:{val_ratio:.2f}")
batch_size = 1
buffer_size = 10
STEPS_PER_EPOCH = int(train_size // batch_size)
print("Steps per Epoch",STEPS_PER_EPOCH)
EPOCHS = 10

VALIDATION_STEPS = val_size//batch_size
print("Validation Steps:",VALIDATION_STEPS)
VAL_SUBSPLITS = 1
# Out:
# num_examples: 2716
# test-train-val-split:
# train_size: 1620 test_size: 548 val_size: 548
# train_ratio:0.60
# test_ratio:0.20
# val_ratio:0.20
# Steps per Epoch 1620
# Validation Steps: 548

# %%
img_size =(160,160)
# Instantiate data Sequences for each split
train_gen = DroneImages(batch_size, img_size, train_dataset_images, train_dataset_masks)
val_gen = DroneImages(batch_size, img_size, val_dataset_images, val_dataset_masks)
test_gen= DroneImages(batch_size, img_size, test_dataset_images, test_dataset_masks)

# %%
"""
Developing the Model Convolutional autoencoder Using Keras Functional API
https://blog.keras.io/building-autoencoders-in-keras.html
By Francois Chollet

"""
# Out:
# '\nDeveloping the Model Convolutional autoencoder Using Keras Functional API\nhttps://blog.keras.io/building-autoencoders-in-keras.html\nBy Francois Chollet\n\n'

# %%
input_img = tf.keras.Input(shape=(160, 160, 3))

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = tf.keras.layers.MaxPooling2D((2, 2), padding='same')(x)

# At this point the representation is (7, 7, 32)

x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = tf.keras.layers.UpSampling2D((2, 2))(x)
decoded = tf.keras.layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = tf.keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
print(autoencoder.summary())
# Out:
# Model: "model_31"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_38 (InputLayer)        [(None, 160, 160, 3)]     0
# _________________________________________________________________
# conv2d_234 (Conv2D)          (None, 160, 160, 32)      896
# _________________________________________________________________
# max_pooling2d_96 (MaxPooling (None, 80, 80, 32)        0
# _________________________________________________________________
# conv2d_235 (Conv2D)          (None, 80, 80, 32)        9248
# _________________________________________________________________
# max_pooling2d_97 (MaxPooling (None, 40, 40, 32)        0
# _________________________________________________________________
# conv2d_236 (Conv2D)          (None, 40, 40, 32)        9248
# _________________________________________________________________
# up_sampling2d_90 (UpSampling (None, 80, 80, 32)        0
# _________________________________________________________________
# conv2d_237 (Conv2D)          (None, 80, 80, 32)        9248
# _________________________________________________________________
# up_sampling2d_91 (UpSampling (None, 160, 160, 32)      0
# _________________________________________________________________
# conv2d_238 (Conv2D)          (None, 160, 160, 3)       867
# =================================================================
# Total params: 29,507
# Trainable params: 29,507
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
train_preds = autoencoder.predict(train_gen)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x2f7daa310> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x2f7daa310> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
 """Quick utility to display a model's prediction."""
def display_mask(i):
   
    mask = train_preds[i]
    #mask = np.resize(mask,(128,128,3))
    #mask = np.argmax(train_preds[i], axis=-1)
    mask = tf.keras.preprocessing.image.array_to_img(mask)
    plt.imshow(mask)
    #display(mask)
   
i=199

# Display input image
display(Image(filename=train_dataset_images[i]))

# Display ground-truth target mask
#img = PIL.ImageOps.autocontrast(keras.preprocessing.image.load_img(test_dataset_masks[i]))
img = PIL.Image.open(train_dataset_masks[i])
display(img)

# Display mask predicted by our model
display_mask(i)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=334x188 at 0x2F7F85970>

# %%
model_history=autoencoder.fit(train_gen,
                epochs=5,
                batch_size=batch_size,
                validation_data=val_gen)
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x8a52443a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x8a52443a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1620/1620 [==============================] - ETA: 0s - loss: 0.0225 - accuracy: 0.8947WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x8a521ed30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x8a521ed30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1620/1620 [==============================] - 48s 30ms/step - loss: 0.0225 - accuracy: 0.8948 - val_loss: 2.4804e-04 - val_accuracy: 0.9999
# Epoch 2/5
# 1620/1620 [==============================] - 47s 29ms/step - loss: 3.1348e-04 - accuracy: 0.9999 - val_loss: 2.4786e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 1620/1620 [==============================] - 47s 29ms/step - loss: 2.9332e-04 - accuracy: 1.0000 - val_loss: 2.3132e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 1620/1620 [==============================] - 48s 30ms/step - loss: 2.9436e-04 - accuracy: 1.0000 - val_loss: 2.4105e-04 - val_accuracy: 1.0000
# Epoch 5/5
# 1620/1620 [==============================] - 47s 29ms/step - loss: 2.9623e-04 - accuracy: 1.0000 - val_loss: 2.7820e-04 - val_accuracy: 1.0000

# %%
test_preds = autoencoder.predict(test_gen)

# %%
pred_mask=test_preds[5]
pred_mask= np.absolute((pred_mask-np.mean(pred_mask))/np.sqrt(np.var(pred_mask)))
pred_mask = tf.keras.preprocessing.image.array_to_img(pred_mask)
print(pred_mask)
plt.imshow(pred_mask)
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x11008D340>

# %%
 """display a model's prediction."""
def display_mask(i):
    pred_mask = test_preds[i]
    #pred_mask = np.argmax(pred_mask[i], axis=-1)
    #pred_mask = np.resize(pred_mask,(128,128,3))
    pred_mask= np.absolute((pred_mask-np.mean(pred_mask))/np.sqrt(np.var(pred_mask)))
    pred_mask = tf.keras.preprocessing.image.array_to_img(pred_mask)
    plt.imshow(pred_mask)
   
   
i=89

# Display input image
display(Image(filename=test_dataset_images[i]))

# Display ground-truth target mask
#img = PIL.ImageOps.autocontrast(keras.preprocessing.image.load_img(test_dataset_masks[i]))
img = PIL.Image.open(test_dataset_masks[i])
display(img)

# Display mask predicted by our model
display_mask(i)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=334x188 at 0x110405B20>

# %%
# print(model_history.history.keys())
print(model_history.epoch)
# Out:
# [0, 1, 2, 3, 4]

# %%
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
accuracy = model_history.history['accuracy']
val_accuracy = model_history.history['val_accuracy']
epoch_num = model_history.epoch

plt.plot(epoch_num, loss, 'r', label='Training loss')
plt.plot(epoch_num, val_loss, 'go--', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Loss Value')
plt.title('Training and Validation Loss')
plt.legend()

# %%
plt.plot(epoch_num, accuracy, 'r', label='Training accuracy')
plt.plot(epoch_num, val_accuracy, 'go--', label='Validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy Value')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
print(model_history.history.keys())
print(model_history.epoch)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# [0, 1, 2, 3, 4]

# %%
results = autoencoder.evaluate(test_gen, batch_size=batch_size)
# Out:
# 548/548 [==============================] - 9s 16ms/step - loss: 2.7820e-04 - accuracy: 1.0000

# %%
print("test loss, test accuracy:", results)
# Out:
# test loss, test accuracy: [0.0002782004594337195, 1.0]

# %%
masks_ds=list((os.listdir('Downloads/testimages/masks/')))
images_ds=list((os.listdir('Downloads/testimages/images/')))
imagesdir = 'Downloads/testimages/images/'
masksdir = 'Downloads/testimages/masks/'
print(len(masksdir))
print(len(imagesdir))
test2_dir='Downloads/testimages'
# Out:
# 27
# 28

# %%
imgPath=[] 
for filename in sorted(images_ds):   
               
               # setting image file
               path_img = imagesdir + filename
               #path_mask = masksdir + filename
               # adding images and annotations to dataset
               #self.add_image('dataset', image_id=image_id, path=path_img, annotation= path_bb)
               imgPath.append(path_img)
               #maskPath.append(path_mask) 
maskPath=[]                
for filename in sorted(masks_ds):   
               
               # setting image file
               #path_img = imagesdir + filename
               path_mask = masksdir + filename
               # adding images and annotations to dataset
               #self.add_image('dataset', image_id=image_id, path=path_img, annotation= path_bb)
               #imgPath.append(path_img)
               maskPath.append(path_mask)

# %%
print("Number of samples:", len(maskPath))
for input_path, target_path in zip(imgPath[2:99], maskPath[1:99]):
    print(input_path, "|", target_path)
# Out:
# Number of samples: 101
# Downloads/testimages/images/image1.JPEG | Downloads/testimages/masks/mine_mask1.JPEG
# Downloads/testimages/images/image10.JPEG | Downloads/testimages/masks/mine_mask10.JPEG
# Downloads/testimages/images/image100.JPEG | Downloads/testimages/masks/mine_mask100.JPEG
# Downloads/testimages/images/image11.JPEG | Downloads/testimages/masks/mine_mask11.JPEG
# Downloads/testimages/images/image12.JPEG | Downloads/testimages/masks/mine_mask12.JPEG
# Downloads/testimages/images/image13.JPEG | Downloads/testimages/masks/mine_mask13.JPEG
# Downloads/testimages/images/image14.JPEG | Downloads/testimages/masks/mine_mask14.JPEG
# Downloads/testimages/images/image15.JPEG | Downloads/testimages/masks/mine_mask15.JPEG
# Downloads/testimages/images/image16.JPEG | Downloads/testimages/masks/mine_mask16.JPEG
# Downloads/testimages/images/image17.JPEG | Downloads/testimages/masks/mine_mask17.JPEG
# Downloads/testimages/images/image18.JPEG | Downloads/testimages/masks/mine_mask18.JPEG
# Downloads/testimages/images/image19.JPEG | Downloads/testimages/masks/mine_mask19.JPEG
# Downloads/testimages/images/image2.JPEG | Downloads/testimages/masks/mine_mask2.JPEG
# Downloads/testimages/images/image20.JPEG | Downloads/testimages/masks/mine_mask20.JPEG
# Downloads/testimages/images/image21.JPEG | Downloads/testimages/masks/mine_mask21.JPEG
# Downloads/testimages/images/image22.JPEG | Downloads/testimages/masks/mine_mask22.JPEG
# Downloads/testimages/images/image23.JPEG | Downloads/testimages/masks/mine_mask23.JPEG
# Downloads/testimages/images/image24.JPEG | Downloads/testimages/masks/mine_mask24.JPEG
# Downloads/testimages/images/image25.JPEG | Downloads/testimages/masks/mine_mask25.JPEG
# Downloads/testimages/images/image26.JPEG | Downloads/testimages/masks/mine_mask26.JPEG
# Downloads/testimages/images/image27.JPEG | Downloads/testimages/masks/mine_mask27.JPEG
# Downloads/testimages/images/image28.JPEG | Downloads/testimages/masks/mine_mask28.JPEG
# Downloads/testimages/images/image29.JPEG | Downloads/testimages/masks/mine_mask29.JPEG
# Downloads/testimages/images/image3.JPEG | Downloads/testimages/masks/mine_mask3.JPEG
# Downloads/testimages/images/image30.JPEG | Downloads/testimages/masks/mine_mask30.JPEG
# Downloads/testimages/images/image31.JPEG | Downloads/testimages/masks/mine_mask31.JPEG
# Downloads/testimages/images/image32.JPEG | Downloads/testimages/masks/mine_mask32.JPEG
# Downloads/testimages/images/image33.JPEG | Downloads/testimages/masks/mine_mask33.JPEG
# Downloads/testimages/images/image34.JPEG | Downloads/testimages/masks/mine_mask34.JPEG
# Downloads/testimages/images/image35.JPEG | Downloads/testimages/masks/mine_mask35.JPEG
# Downloads/testimages/images/image36.JPEG | Downloads/testimages/masks/mine_mask36.JPEG
# Downloads/testimages/images/image37.JPEG | Downloads/testimages/masks/mine_mask37.JPEG
# Downloads/testimages/images/image38.JPEG | Downloads/testimages/masks/mine_mask38.JPEG
# Downloads/testimages/images/image39.JPEG | Downloads/testimages/masks/mine_mask39.JPEG
# Downloads/testimages/images/image4.JPEG | Downloads/testimages/masks/mine_mask4.JPEG
# Downloads/testimages/images/image40.JPEG | Downloads/testimages/masks/mine_mask40.JPEG
# Downloads/testimages/images/image41.JPEG | Downloads/testimages/masks/mine_mask41.JPEG
# Downloads/testimages/images/image42.JPEG | Downloads/testimages/masks/mine_mask42.JPEG
# Downloads/testimages/images/image43.JPEG | Downloads/testimages/masks/mine_mask43.JPEG
# Downloads/testimages/images/image44.JPEG | Downloads/testimages/masks/mine_mask44.JPEG
# Downloads/testimages/images/image45.JPEG | Downloads/testimages/masks/mine_mask45.JPEG
# Downloads/testimages/images/image46.JPEG | Downloads/testimages/masks/mine_mask46.JPEG
# Downloads/testimages/images/image47.JPEG | Downloads/testimages/masks/mine_mask47.JPEG
# Downloads/testimages/images/image48.JPEG | Downloads/testimages/masks/mine_mask48.JPEG
# Downloads/testimages/images/image49.JPEG | Downloads/testimages/masks/mine_mask49.JPEG
# Downloads/testimages/images/image5.JPEG | Downloads/testimages/masks/mine_mask5.JPEG
# Downloads/testimages/images/image50.JPEG | Downloads/testimages/masks/mine_mask50.JPEG
# Downloads/testimages/images/image51.JPEG | Downloads/testimages/masks/mine_mask51.JPEG
# Downloads/testimages/images/image52.JPEG | Downloads/testimages/masks/mine_mask52.JPEG
# Downloads/testimages/images/image53.JPEG | Downloads/testimages/masks/mine_mask53.JPEG
# Downloads/testimages/images/image54.JPEG | Downloads/testimages/masks/mine_mask54.JPEG
# Downloads/testimages/images/image55.JPEG | Downloads/testimages/masks/mine_mask55.JPEG
# Downloads/testimages/images/image56.JPEG | Downloads/testimages/masks/mine_mask56.JPEG
# Downloads/testimages/images/image57.JPEG | Downloads/testimages/masks/mine_mask57.JPEG
# Downloads/testimages/images/image58.JPEG | Downloads/testimages/masks/mine_mask58.JPEG
# Downloads/testimages/images/image59.JPEG | Downloads/testimages/masks/mine_mask59.JPEG
# Downloads/testimages/images/image6.JPEG | Downloads/testimages/masks/mine_mask6.JPEG
# Downloads/testimages/images/image60.JPEG | Downloads/testimages/masks/mine_mask60.JPEG
# Downloads/testimages/images/image61.JPEG | Downloads/testimages/masks/mine_mask61.JPEG
# Downloads/testimages/images/image62.JPEG | Downloads/testimages/masks/mine_mask62.JPEG
# Downloads/testimages/images/image63.JPEG | Downloads/testimages/masks/mine_mask63.JPEG
# Downloads/testimages/images/image64.JPEG | Downloads/testimages/masks/mine_mask64.JPEG
# Downloads/testimages/images/image65.JPEG | Downloads/testimages/masks/mine_mask65.JPEG
# Downloads/testimages/images/image66.JPEG | Downloads/testimages/masks/mine_mask66.JPEG
# Downloads/testimages/images/image67.JPEG | Downloads/testimages/masks/mine_mask67.JPEG
# Downloads/testimages/images/image68.JPEG | Downloads/testimages/masks/mine_mask68.JPEG
# Downloads/testimages/images/image69.JPEG | Downloads/testimages/masks/mine_mask69.JPEG
# Downloads/testimages/images/image7.JPEG | Downloads/testimages/masks/mine_mask7.JPEG
# Downloads/testimages/images/image70.JPEG | Downloads/testimages/masks/mine_mask70.JPEG
# Downloads/testimages/images/image71.JPEG | Downloads/testimages/masks/mine_mask71.JPEG
# Downloads/testimages/images/image72.JPEG | Downloads/testimages/masks/mine_mask72.JPEG
# Downloads/testimages/images/image73.JPEG | Downloads/testimages/masks/mine_mask73.JPEG
# Downloads/testimages/images/image74.JPEG | Downloads/testimages/masks/mine_mask74.JPEG
# Downloads/testimages/images/image75.JPEG | Downloads/testimages/masks/mine_mask75.JPEG
# Downloads/testimages/images/image76.JPEG | Downloads/testimages/masks/mine_mask76.JPEG
# Downloads/testimages/images/image77.JPEG | Downloads/testimages/masks/mine_mask77.JPEG
# Downloads/testimages/images/image78.JPEG | Downloads/testimages/masks/mine_mask78.JPEG
# Downloads/testimages/images/image79.JPEG | Downloads/testimages/masks/mine_mask79.JPEG
# Downloads/testimages/images/image8.JPEG | Downloads/testimages/masks/mine_mask8.JPEG
# Downloads/testimages/images/image80.JPEG | Downloads/testimages/masks/mine_mask80.JPEG
# Downloads/testimages/images/image81.JPEG | Downloads/testimages/masks/mine_mask81.JPEG
# Downloads/testimages/images/image82.JPEG | Downloads/testimages/masks/mine_mask82.JPEG
# Downloads/testimages/images/image83.JPEG | Downloads/testimages/masks/mine_mask83.JPEG
# Downloads/testimages/images/image84.JPEG | Downloads/testimages/masks/mine_mask84.JPEG
# Downloads/testimages/images/image85.JPEG | Downloads/testimages/masks/mine_mask85.JPEG
# Downloads/testimages/images/image86.JPEG | Downloads/testimages/masks/mine_mask86.JPEG
# Downloads/testimages/images/image87.JPEG | Downloads/testimages/masks/mine_mask87.JPEG
# Downloads/testimages/images/image88.JPEG | Downloads/testimages/masks/mine_mask88.JPEG
# Downloads/testimages/images/image89.JPEG | Downloads/testimages/masks/mine_mask89.JPEG
# Downloads/testimages/images/image9.JPEG | Downloads/testimages/masks/mine_mask9.JPEG
# Downloads/testimages/images/image90.JPEG | Downloads/testimages/masks/mine_mask90.JPEG
# Downloads/testimages/images/image91.JPEG | Downloads/testimages/masks/mine_mask91.JPEG
# Downloads/testimages/images/image92.JPEG | Downloads/testimages/masks/mine_mask92.JPEG
# Downloads/testimages/images/image93.JPEG | Downloads/testimages/masks/mine_mask93.JPEG
# Downloads/testimages/images/image94.JPEG | Downloads/testimages/masks/mine_mask94.JPEG
# Downloads/testimages/images/image95.JPEG | Downloads/testimages/masks/mine_mask95.JPEG
# Downloads/testimages/images/image96.JPEG | Downloads/testimages/masks/mine_mask96.JPEG

# %%
img2_size=(160,160)
batch_size=1
test2_gen = DroneImages(batch_size, img2_size, imgPath[2:99], maskPath[1:99])

# %%
print(len(test2_gen))
# Out:
# 98

# %%
test2_preds=autoencoder.predict(test2_gen)

# %%
def display_mask(i):
    """Quick utility to display a model's prediction."""
    
    pred_mask = test2_preds[i]
    #pred_mask = np.argmax(pred_mask[i], axis=-1)
    #pred_mask = np.resize(pred_mask,(600,400,3))
    pred_mask= np.absolute((pred_mask-np.mean(pred_mask))/np.sqrt(np.var(pred_mask)))
    #pred_mask = tf.keras.preprocessing.image.array_to_img(pred_mask)
    plt.imshow(pred_mask)
i=9

# Display ground-truth target image
img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.load_img(imgPath[i]))
display(img)



# Display ground-truth target mask
img = PIL.ImageOps.autocontrast(tf.keras.preprocessing.image.load_img(maskPath[i]))
display(img)

# Display mask predicted by our model
display_mask(i)
# Out:
# <PIL.Image.Image image mode=RGB size=216x288 at 0x113FF58B0>
# <PIL.Image.Image image mode=RGB size=216x288 at 0x11067AA00>
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
